# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
class binomial:
    def __init__(self, N, p): 
        self.N = N 
        self.p = p 
        
    def sample(self,n=1):
        output = []
        for rep in range(n):
            X = 0
            for i in range(self.N):
                u = random.random() 
                if u < self.p: 
                    X = X+1
            output.append(X)
        return output

# %%
binom = binomial(N=20,p=0.5)
out = binom.sample(100000)
plt.hist(out, bins = np.arange(-0.5,21,0.5))
# Out:
# (array([0.0000e+00, 0.0000e+00, 0.0000e+00, 4.0000e+00, 0.0000e+00,
#         2.2000e+01, 0.0000e+00, 1.0800e+02, 0.0000e+00, 4.8500e+02,
#         0.0000e+00, 1.5060e+03, 0.0000e+00, 3.7270e+03, 0.0000e+00,
#         7.3960e+03, 0.0000e+00, 1.1835e+04, 0.0000e+00, 1.6064e+04,
#         0.0000e+00, 1.7522e+04, 0.0000e+00, 1.6078e+04, 0.0000e+00,
#         1.2168e+04, 0.0000e+00, 7.4650e+03, 0.0000e+00, 3.5730e+03,
#         0.0000e+00, 1.4840e+03, 0.0000e+00, 4.4200e+02, 0.0000e+00,
#         9.9000e+01, 0.0000e+00, 2.0000e+01, 0.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00]),
#  array([-0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,
#          5. ,  5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. ,
#         10.5, 11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5,
#         16. , 16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5]),
#  <BarContainer object of 42 artists>)

# %%
np.random.binomial?
